# %% [markdown]
# <a href="https://colab.research.google.com/github/santhanreddy864/In-class-exercise-1/blob/main/In_class_exercise_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The fourth in-class-exercise (20 points in total, 2/9/2021)**

# %% [markdown]
# # 1. Text Data Preprocessing
#
# Here is a [legal case](https://github.com/unt-iialab/info5731_spring2021/blob/main/class_exercises/01-05-1%20%20Adams%20v%20Tanner.txt) we collected from westlaw, please follow the steps we mentioned in lesson 5 to clean the data:
#
#
#
# ## 1.1 Basic feature extraction using text data (4 points)
#
# *   Number of sentences
# *   Number of words
# *   Number of characters
# *   Average word length
# *   Number of stopwords
# *   Number of special characters
# *   Number of numerics
# *   Number of uppercase words
#
# ## 1.2 Basic Text Pre-processing of text data (4 points)
#
# *   Lower casing
# *   Punctuation removal
# *   Stopwords removal
# *   Frequent words removal
# *   Rare words removal
# *   Spelling correction
# *   Tokenization
# *   Stemming
# *   Lemmatization
#
# ## 1.3 Save all the **clean sentences** to a **csv file** (one column, each raw is a sentence) after finishing all the steps above. (4 points)
#
#
# ## 1.4 Advance Text Processing (Extra credit: 4 points)
#
# *   Calculate the term frequency of all the terms.
# *   Print out top 10 1-gram, top 10 2-grams, and top 10 3-grams terms as features.

# %%
#  Basic feature extraction using text data
import pandas as pd
from six.moves import urllib
array = []
url = "https://raw.githubusercontent.com/unt-iialab/info5731_spring2021/main/class_exercises/01-05-1%20%20Adams%20v%20Tanner.txt"
x = urllib.request.urlopen(url)
for f in x:
  d = f.decode("utf-8").replace('\r\n', '')
  if d:
    array.append(d)

df = pd.DataFrame (array, columns = ['Raw Text'])    
print(df)
# Out:
#                                               Raw Text
# 0                                           5 Ala. 740
# 1                            Supreme Court of Alabama.
# 2                                                ADAMS
# 3                                                   v.
# 4                                   TANNER AND HORTON.
# ..                                                 ...
# 143            There are no Filings for this citation.
# 144                                 Negative Treatment
# 145  There are no Negative Treatment results for th...
# 146                                            History
# 147    There are no History results for this citation.
#
# [148 rows x 1 columns]

# %%
#total sentences
df['No of sentences'] = df['Raw Text'].apply(lambda x: len(str(x).split(".")))
df
# Out:
#                                               Raw Text  ...  No of sentences
# 0                                           5 Ala. 740  ...                2
# 1                            Supreme Court of Alabama.  ...                2
# 2                                                ADAMS  ...                1
# 3                                                   v.  ...                2
# 4                                   TANNER AND HORTON.  ...                2
# ..                                                 ...  ...              ...
# 143            There are no Filings for this citation.  ...                2
# 144                                 Negative Treatment  ...                1
# 145  There are no Negative Treatment results for th...  ...                2
# 146                                            History  ...                1
# 147    There are no History results for this citation.  ...                2
#
# [148 rows x 3 columns]

# %%
#total words
df['No of Words'] = df['Raw Text'].apply(lambda x: len(str(x).split(" ")))
df
# Out:
#                                               Raw Text  ...  No of Words
# 0                                           5 Ala. 740  ...            3
# 1                            Supreme Court of Alabama.  ...            4
# 2                                                ADAMS  ...            1
# 3                                                   v.  ...            1
# 4                                   TANNER AND HORTON.  ...            3
# ..                                                 ...  ...          ...
# 143            There are no Filings for this citation.  ...            7
# 144                                 Negative Treatment  ...            2
# 145  There are no Negative Treatment results for th...  ...            9
# 146                                            History  ...            1
# 147    There are no History results for this citation.  ...            8
#
# [148 rows x 4 columns]

# %%
#total characters
df['No of Characters'] = df['Raw Text'].str.len()
df
# Out:
#                                               Raw Text  ...  No of Characters
# 0                                           5 Ala. 740  ...                10
# 1                            Supreme Court of Alabama.  ...                25
# 2                                                ADAMS  ...                 5
# 3                                                   v.  ...                 2
# 4                                   TANNER AND HORTON.  ...                18
# ..                                                 ...  ...               ...
# 143            There are no Filings for this citation.  ...                39
# 144                                 Negative Treatment  ...                18
# 145  There are no Negative Treatment results for th...  ...                58
# 146                                            History  ...                 7
# 147    There are no History results for this citation.  ...                47
#
# [148 rows x 5 columns]

# %%
#average word length
def avg(sent):
  x = sent.split()
  if len(x) != 0:
    return(sum(len(word) for word in x)/len(x))
  else:
    return None
df['Avg Word Length'] = df['Raw Text'].apply(lambda x: avg(x))
df
# Out:
#                                               Raw Text  ...  Avg Word Length
# 0                                           5 Ala. 740  ...         2.666667
# 1                            Supreme Court of Alabama.  ...         5.500000
# 2                                                ADAMS  ...         5.000000
# 3                                                   v.  ...         2.000000
# 4                                   TANNER AND HORTON.  ...         5.333333
# ..                                                 ...  ...              ...
# 143            There are no Filings for this citation.  ...         4.714286
# 144                                 Negative Treatment  ...         8.500000
# 145  There are no Negative Treatment results for th...  ...         5.555556
# 146                                            History  ...         7.000000
# 147    There are no History results for this citation.  ...         5.000000
#
# [148 rows x 6 columns]

# %%
#number of stopwords
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop = stopwords.words('english')
df['No of Stopwords'] = df['Raw Text'].apply(lambda x: len([x for x in x.split() if x in stop]))
df
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                               Raw Text  ...  No of Stopwords
# 0                                           5 Ala. 740  ...                0
# 1                            Supreme Court of Alabama.  ...                1
# 2                                                ADAMS  ...                0
# 3                                                   v.  ...                0
# 4                                   TANNER AND HORTON.  ...                0
# ..                                                 ...  ...              ...
# 143            There are no Filings for this citation.  ...                4
# 144                                 Negative Treatment  ...                0
# 145  There are no Negative Treatment results for th...  ...                4
# 146                                            History  ...                0
# ...

# %%
#number of special characters
def char(sent):
  x = 0
  for y in range(len(sent)):
    if not((sent[y].isalpha()) and (sent[y].isdigit())):
        x = x + 1
  return x
df['No of special characters'] = df['Raw Text'].apply(lambda x: char(x))
df
# Out:
#                                               Raw Text  ...  No of special characters
# 0                                           5 Ala. 740  ...                        10
# 1                            Supreme Court of Alabama.  ...                        25
# 2                                                ADAMS  ...                         5
# 3                                                   v.  ...                         2
# 4                                   TANNER AND HORTON.  ...                        18
# ..                                                 ...  ...                       ...
# 143            There are no Filings for this citation.  ...                        39
# 144                                 Negative Treatment  ...                        18
# 145  There are no Negative Treatment results for th...  ...                        58
# 146                                            History  ...                         7
# ...

# %%
#number of numerics
df['No of numerics'] = df['Raw Text'].apply(lambda x: len([x for x in x.split() if x.isdigit()]))
df
# Out:
#                                               Raw Text  ...  No of numerics
# 0                                           5 Ala. 740  ...               2
# 1                            Supreme Court of Alabama.  ...               0
# 2                                                ADAMS  ...               0
# 3                                                   v.  ...               0
# 4                                   TANNER AND HORTON.  ...               0
# ..                                                 ...  ...             ...
# 143            There are no Filings for this citation.  ...               0
# 144                                 Negative Treatment  ...               0
# 145  There are no Negative Treatment results for th...  ...               0
# 146                                            History  ...               0
# 147    There are no History results for this citation.  ...               0
#
# [148 rows x 11 columns]

# %%
#Number of uppercase words
df['No of upper case words'] = df['Raw Text'].apply(lambda x: len([x for x in x.split() if x.isupper()]))
df
# Out:
#                                               Raw Text  ...  No of upper case words
# 0                                           5 Ala. 740  ...                       0
# 1                            Supreme Court of Alabama.  ...                       0
# 2                                                ADAMS  ...                       1
# 3                                                   v.  ...                       0
# 4                                   TANNER AND HORTON.  ...                       3
# ..                                                 ...  ...                     ...
# 143            There are no Filings for this citation.  ...                       0
# 144                                 Negative Treatment  ...                       0
# 145  There are no Negative Treatment results for th...  ...                       0
# 146                                            History  ...                       0
# ...

# %%
#Basic Text Pre-processing of text data

#Lower casing
df['Lower Case'] = df['Raw Text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df
# Out:
#                                               Raw Text  ...                                         Lower Case
# 0                                           5 Ala. 740  ...                                         5 ala. 740
# 1                            Supreme Court of Alabama.  ...                          supreme court of alabama.
# 2                                                ADAMS  ...                                              adams
# 3                                                   v.  ...                                                 v.
# 4                                   TANNER AND HORTON.  ...                                 tanner and horton.
# ..                                                 ...  ...                                                ...
# 143            There are no Filings for this citation.  ...            there are no filings for this citation.
# ...

# %%
#Punctuation removal
df['Punctuation removal'] = df['Lower Case'].str.replace('[^\w\s]','')
df
# Out:
#                                               Raw Text  ...                                Punctuation removal
# 0                                           5 Ala. 740  ...                                          5 ala 740
# 1                            Supreme Court of Alabama.  ...                           supreme court of alabama
# 2                                                ADAMS  ...                                              adams
# 3                                                   v.  ...                                                  v
# 4                                   TANNER AND HORTON.  ...                                  tanner and horton
# ..                                                 ...  ...                                                ...
# 143            There are no Filings for this citation.  ...             there are no filings for this citation
# ...

# %%
#Stopwords removal
import nltk
from nltk.corpus import stopwords
remove = stopwords.words('english')
df['Stopwords Removal'] = df['Punctuation removal'].apply(lambda x: " ".join(x for x in x.split() if x not in remove))
df
# Out:
#                                               Raw Text  ...                    Stopwords Removal
# 0                                           5 Ala. 740  ...                            5 ala 740
# 1                            Supreme Court of Alabama.  ...                supreme court alabama
# 2                                                ADAMS  ...                                adams
# 3                                                   v.  ...                                    v
# 4                                   TANNER AND HORTON.  ...                        tanner horton
# ..                                                 ...  ...                                  ...
# 143            There are no Filings for this citation.  ...                     filings citation
# 144                                 Negative Treatment  ...                   negative treatment
# 145  There are no Negative Treatment results for th...  ...  negative treatment results citation
# ...

# %%
#Frequent words removal
x = pd.Series(' '.join(df['Stopwords Removal']).split()).value_counts()[:10]
print(x)
y = list(x.index)
df[' Removed common words'] = df['Stopwords Removal'].apply(lambda x: " ".join(x for x in x.split() if x not in y))
df
# Out:
# execution    50
# crop         49
# levy         25
# lien         25
# v            22
# claimants    22
# case         21
# right        21
# court        20
# gathered     19
# dtype: int64
#                                               Raw Text  ...                 Removed common words
# 0                                           5 Ala. 740  ...                            5 ala 740
# 1                            Supreme Court of Alabama.  ...                      supreme alabama
# 2                                                ADAMS  ...                                adams
# 3                                                   v.  ...
# 4                                   TANNER AND HORTON.  ...                        tanner horton
# ..                                                 ...  ...                                  ...
# 143            There are no Filings for this citation.  ...                     filings citation
# ...

# %%
#Rare words removal
x = pd.Series(' '.join(df['Stopwords Removal']).split()).value_counts()[-10:]
print(x)
y = list(x.index)
df[' Removed rare words'] = df['After common words removal'].apply(lambda x: " ".join(x for x in x.split() if x not in y))
df
# Out:
# 418              1
# performance      1
# claimant         1
# 258              1
# specific         1
# temporary        1
# perhaps          1
# retrospective    1
# jun              1
# compel           1
# dtype: int64
#                                               Raw Text  ...                   Removed rare words
# 0                                           5 Ala. 740  ...                            5 ala 740
# 1                            Supreme Court of Alabama.  ...                      supreme alabama
# 2                                                ADAMS  ...                                adams
# 3                                                   v.  ...
# 4                                   TANNER AND HORTON.  ...                        tanner horton
# ..                                                 ...  ...                                  ...
# 143            There are no Filings for this citation.  ...                     filings citation
# ...

# %%
#Spelling correction
from textblob import TextBlob
df['Spelling Correction'] = df['After Rare Words removal'].apply(lambda x: str(TextBlob(x).correct()))
df
# Out:
#                                               Raw Text  ...                   Spelling Correction
# 0                                           5 Ala. 740  ...                             5 all 740
# 1                            Supreme Court of Alabama.  ...                       supreme alabama
# 2                                                ADAMS  ...                                 adams
# 3                                                   v.  ...
# 4                                   TANNER AND HORTON.  ...                         manner norton
# ..                                                 ...  ...                                   ...
# 143            There are no Filings for this citation.  ...                      filing situation
# 144                                 Negative Treatment  ...                    negative treatment
# 145  There are no Negative Treatment results for th...  ...  negative treatment results situation
# ...

# %%
#Tokenization
import nltk
nltk.download('punkt')
df['Tokenization'] = df['Spelling Correction'].apply(lambda x: TextBlob(x).words)
df
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                               Raw Text  ...                               Tokenization
# 0                                           5 Ala. 740  ...                              [5, all, 740]
# 1                            Supreme Court of Alabama.  ...                         [supreme, alabama]
# 2                                                ADAMS  ...                                    [adams]
# 3                                                   v.  ...                                         []
# 4                                   TANNER AND HORTON.  ...                           [manner, norton]
# ..                                                 ...  ...                                        ...
# 143            There are no Filings for this citation.  ...                        [filing, situation]
# ...

# %%
#Stemming
from nltk.stem import PorterStemmer
st = PorterStemmer()
df[' Stemming'] = df['Tokenization'].apply(lambda x: " ".join([st.stem(word) for word in x]))
df
# Out:
#                                               Raw Text  ...                     Stemming
# 0                                           5 Ala. 740  ...                    5 all 740
# 1                            Supreme Court of Alabama.  ...               suprem alabama
# 2                                                ADAMS  ...                         adam
# 3                                                   v.  ...
# 4                                   TANNER AND HORTON.  ...                manner norton
# ..                                                 ...  ...                          ...
# 143            There are no Filings for this citation.  ...                  file situat
# 144                                 Negative Treatment  ...                neg treatment
# 145  There are no Negative Treatment results for th...  ...  neg treatment result situat
# 146                                            History  ...                      histori
# ...

# %%
#Lemmatization
from textblob import Word
import nltk
nltk.download('wordnet')
df['Lemmatization'] = df[' Stemming'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
df
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                               Raw Text  ...                Lemmatization
# 0                                           5 Ala. 740  ...                    5 all 740
# 1                            Supreme Court of Alabama.  ...               suprem alabama
# 2                                                ADAMS  ...                         adam
# 3                                                   v.  ...
# 4                                   TANNER AND HORTON.  ...                manner norton
# ..                                                 ...  ...                          ...
# 143            There are no Filings for this citation.  ...                  file situat
# 144                                 Negative Treatment  ...                neg treatment
# 145  There are no Negative Treatment results for th...  ...  neg treatment result situat
# ...

# %%
#saving it to csv
df.to_csv('cleaned_data.csv',index=False)

# %%
#Advance Text Processing

#Calculating Term frequencies
x = (df['Lemmatization']).apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0).reset_index()
x.columns = ['words','term_fre']
x
# Out:
#        words  term_fre
# 0        all      17.0
# 1        740       2.0
# 2          5       8.0
# 3    alabama       1.0
# 4     suprem       1.0
# ..       ...       ...
# 699      let       1.0
# 700    grain       1.0
# 701     file       2.0
# 702      neg       2.0
# 703  histori       2.0
#
# [704 rows x 2 columns]

# %% [markdown]
# # 2. Python Regular Expression

# %% [markdown]
# ## 2.1 Write a Python program to remove leading zeros from an IP address. (4 points)
#
# ip = "260.08.094.109"

# %%
import re
ip = "260.08.094.109"
x = re.sub('\.[0]*', '.', ip)
print(x)
# Out:
# 260.8.94.109

# %% [markdown]
# ## 2.2 Write a Python Program to extract all the years from the following sentence. (4 points)
#
# sentence = "The 2010s were a dramatic decade, filled with ups and downs, more than 1000 stroies have happened. As the decade comes to a close, Insider took a look back at some of the biggest headline-grabbing stories, from 2010 to 2019. The result was 119 news stories that ranged from the heartwarming rescue of a Thai boys' soccer team from a flooded cave to the divisive election of President Donald Trump."

# %%
import re
x = "The 2010s were a dramatic decade, filled with ups and downs, more than 1000 stroies have happened. As the decade comes to a close, Insider took a look back at some of the biggest headline-grabbing stories, from 2010 to 2019. The result was 119 news stories that ranged from the heartwarming rescue of a Thai boys' soccer team from a flooded cave to the divisive election of President Donald Trump."
years = re.findall(r'2\d\d\d', x)
print("extracted years from the following sentence:",years)
# Out:
# extracted years from the following sentence: ['2010', '2010', '2019']
